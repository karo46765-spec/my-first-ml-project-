# %%
import numpy as np

Credit_score = np.array([620,710,790])

application_matrix = np.array([[5000,1200],[6200,1500],[8000,800],])

print(f"Credit Scores shape : {Credit_score.shape}")
print(f"{application_matrix.shape}")
# Out:
# Credit Scores shape : (3,)
# (3, 2)

# %%
inflation_matrix = application_matrix*1.05

# %%
inflation_matrix
# Out:
# array([[5250., 1260.],
#        [6510., 1575.],
#        [8400.,  840.]])

# %%
dept_Sum = application_matrix[:,1].sum()

# %%
dept_Sum
# Out:
# np.int64(3500)

# %%
print("\n--Processed matrix--")
print("inflated matrix (income & depth adjusted up 5%): ")
print(inflation_matrix)

print(f"\n Total System Dept : ${dept_Sum}")
# Out:
# --Processed matrix--
# inflated matrix (income & depth adjusted up 5%):
# [[5250. 1260.]
#  [6510. 1575.]
#  [8400.  840.]]
#
#  Total System Dept : $3500
